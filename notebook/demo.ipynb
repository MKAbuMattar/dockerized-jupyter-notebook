# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
# Out:
# 2023-11-27 19:30:19.771309: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-27 19:30:19.861964: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-27 19:30:19.861998: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-27 19:30:19.863423: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-27 19:30:19.873321: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-27 19:30:19.873892: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-27 19:30:20.752020: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
config = ConfigProto()
config.gpu_options.allow_growth = False
session = InteractiveSession(config=config)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
print("Test on CPU")

with tf.device("/cpu:0"):
    num_classes = 10
    input_shape = (28, 28, 1)
    (x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
    x_train = x_train.astype("float32") / 255
    x_test = x_test.astype("float32") / 255
    x_train = np.expand_dims(x_train, -1)
    x_test = np.expand_dims(x_test, -1)
    print("x_train shape:", x_train.shape)
    print(x_train.shape[0], "train samples")
    print(x_test.shape[0], "test samples")
    y_train = keras.utils.to_categorical(y_train, num_classes)
    y_test = keras.utils.to_categorical(y_test, num_classes)
    model = keras.Sequential(
        [
            keras.Input(shape=input_shape),
            layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
            layers.MaxPooling2D(pool_size=(2, 2)),
            layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
            layers.MaxPooling2D(pool_size=(2, 2)),
            layers.Flatten(),
            layers.Dropout(0.5),
            layers.Dense(num_classes, activation="softmax"),
        ]
    )
    model.summary()
    batch_size = 128
    epochs = 15
    model.compile(
        loss="categorical_crossentropy",
        optimizer="adam",
        metrics=["accuracy"]
    )
    model.fit(
        x_train,
        y_train,
        batch_size=batch_size,
        epochs=epochs,
        validation_split=0.1
    )
# Out:
# Test on CPU
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dropout (Dropout)           (None, 1600)              0
#
#  dense (Dense)               (None, 10)                16010
#
# =================================================================
# Total params: 34826 (136.04 KB)
# Trainable params: 34826 (136.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/15
# 422/422 [==============================] - 19s 44ms/step - loss: 0.3729 - accuracy: 0.8848 - val_loss: 0.0865 - val_accuracy: 0.9780
# Epoch 2/15
# 422/422 [==============================] - 20s 48ms/step - loss: 0.1179 - accuracy: 0.9636 - val_loss: 0.0597 - val_accuracy: 0.9827
# Epoch 3/15
# 422/422 [==============================] - 21s 49ms/step - loss: 0.0894 - accuracy: 0.9724 - val_loss: 0.0503 - val_accuracy: 0.9862
# Epoch 4/15
# 422/422 [==============================] - 20s 48ms/step - loss: 0.0750 - accuracy: 0.9771 - val_loss: 0.0430 - val_accuracy: 0.9878
# Epoch 5/15
# 422/422 [==============================] - 20s 48ms/step - loss: 0.0644 - accuracy: 0.9796 - val_loss: 0.0461 - val_accuracy: 0.9882
# Epoch 6/15
# 422/422 [==============================] - 20s 47ms/step - loss: 0.0581 - accuracy: 0.9817 - val_loss: 0.0373 - val_accuracy: 0.9897
# Epoch 7/15
# 422/422 [==============================] - 20s 48ms/step - loss: 0.0526 - accuracy: 0.9832 - val_loss: 0.0351 - val_accuracy: 0.9917
# Epoch 8/15
# 422/422 [==============================] - 20s 48ms/step - loss: 0.0479 - accuracy: 0.9848 - val_loss: 0.0334 - val_accuracy: 0.9913
# Epoch 9/15
# 422/422 [==============================] - 20s 48ms/step - loss: 0.0448 - accuracy: 0.9861 - val_loss: 0.0326 - val_accuracy: 0.9912
# Epoch 10/15
# 422/422 [==============================] - 20s 48ms/step - loss: 0.0409 - accuracy: 0.9870 - val_loss: 0.0312 - val_accuracy: 0.9932
# Epoch 11/15
# 422/422 [==============================] - 20s 48ms/step - loss: 0.0393 - accuracy: 0.9880 - val_loss: 0.0297 - val_accuracy: 0.9917
# Epoch 12/15
# 422/422 [==============================] - 20s 47ms/step - loss: 0.0389 - accuracy: 0.9872 - val_loss: 0.0323 - val_accuracy: 0.9915
# Epoch 13/15
# 422/422 [==============================] - 20s 47ms/step - loss: 0.0368 - accuracy: 0.9879 - val_loss: 0.0296 - val_accuracy: 0.9917
# Epoch 14/15
# 422/422 [==============================] - 20s 47ms/step - loss: 0.0335 - accuracy: 0.9891 - val_loss: 0.0287 - val_accuracy: 0.9930
# Epoch 15/15
# 422/422 [==============================] - 20s 48ms/step - loss: 0.0328 - accuracy: 0.9894 - val_loss: 0.0297 - val_accuracy: 0.9920

# %%
print("Test on GPU")

with tf.device("/gpu:0"):
    num_classes = 10
    input_shape = (28, 28, 1)
    (x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
    x_train = x_train.astype("float32") / 255
    x_test = x_test.astype("float32") / 255
    x_train = np.expand_dims(x_train, -1)
    x_test = np.expand_dims(x_test, -1)
    print("x_train shape:", x_train.shape)
    print(x_train.shape[0], "train samples")
    print(x_test.shape[0], "test samples")
    y_train = keras.utils.to_categorical(y_train, num_classes)
    y_test = keras.utils.to_categorical(y_test, num_classes)
    model = keras.Sequential(
        [
            keras.Input(shape=input_shape),
            layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
            layers.MaxPooling2D(pool_size=(2, 2)),
            layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
            layers.MaxPooling2D(pool_size=(2, 2)),
            layers.Flatten(),
            layers.Dropout(0.5),
            layers.Dense(num_classes, activation="softmax"),
        ]
    )
    model.summary()
    batch_size = 128
    epochs = 15
    model.compile(
        loss="categorical_crossentropy",
        optimizer="adam",
        metrics=["accuracy"]
    )
    model.fit(
        x_train, y_train,
        batch_size=batch_size,
        epochs=epochs,
        validation_split=0.1
    )
# Out:
# Test on GPU
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_2 (MaxPoolin  (None, 13, 13, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_3 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 1600)              0
#
#  dropout_1 (Dropout)         (None, 1600)              0
#
#  dense_1 (Dense)             (None, 10)                16010
#
# =================================================================
# Total params: 34826 (136.04 KB)
# Trainable params: 34826 (136.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/15
# 422/422 [==============================] - 19s 43ms/step - loss: 0.3650 - accuracy: 0.8898 - val_loss: 0.0816 - val_accuracy: 0.9778
# Epoch 2/15
# 422/422 [==============================] - 19s 45ms/step - loss: 0.1115 - accuracy: 0.9657 - val_loss: 0.0591 - val_accuracy: 0.9847
# Epoch 3/15
# 422/422 [==============================] - 19s 46ms/step - loss: 0.0855 - accuracy: 0.9737 - val_loss: 0.0482 - val_accuracy: 0.9882
# Epoch 4/15
# 422/422 [==============================] - 19s 46ms/step - loss: 0.0715 - accuracy: 0.9780 - val_loss: 0.0405 - val_accuracy: 0.9885
# Epoch 5/15
# 422/422 [==============================] - 19s 46ms/step - loss: 0.0633 - accuracy: 0.9807 - val_loss: 0.0397 - val_accuracy: 0.9890
# Epoch 6/15
# 422/422 [==============================] - 19s 46ms/step - loss: 0.0563 - accuracy: 0.9821 - val_loss: 0.0373 - val_accuracy: 0.9892
# Epoch 7/15
# 422/422 [==============================] - 20s 46ms/step - loss: 0.0506 - accuracy: 0.9843 - val_loss: 0.0368 - val_accuracy: 0.9898
# Epoch 8/15
# 422/422 [==============================] - 20s 47ms/step - loss: 0.0484 - accuracy: 0.9846 - val_loss: 0.0322 - val_accuracy: 0.9922
# Epoch 9/15
# 422/422 [==============================] - 20s 46ms/step - loss: 0.0439 - accuracy: 0.9859 - val_loss: 0.0343 - val_accuracy: 0.9902
# Epoch 10/15
# 422/422 [==============================] - 19s 46ms/step - loss: 0.0424 - accuracy: 0.9860 - val_loss: 0.0344 - val_accuracy: 0.9902
# Epoch 11/15
# 422/422 [==============================] - 19s 46ms/step - loss: 0.0384 - accuracy: 0.9883 - val_loss: 0.0320 - val_accuracy: 0.9907
# Epoch 12/15
# 422/422 [==============================] - 19s 46ms/step - loss: 0.0370 - accuracy: 0.9881 - val_loss: 0.0300 - val_accuracy: 0.9920
# Epoch 13/15
# 422/422 [==============================] - 20s 47ms/step - loss: 0.0352 - accuracy: 0.9889 - val_loss: 0.0324 - val_accuracy: 0.9918
# Epoch 14/15
# 422/422 [==============================] - 20s 46ms/step - loss: 0.0345 - accuracy: 0.9887 - val_loss: 0.0289 - val_accuracy: 0.9923
# Epoch 15/15
# 422/422 [==============================] - 20s 46ms/step - loss: 0.0311 - accuracy: 0.9899 - val_loss: 0.0306 - val_accuracy: 0.9917
