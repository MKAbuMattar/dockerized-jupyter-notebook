# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
# Out:
# 2023-07-08 15:41:29.916849: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-08 15:41:29.964461: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-08 15:41:29.965710: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-08 15:41:30.940412: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
config = ConfigProto()
config.gpu_options.allow_growth = False
session = InteractiveSession(config=config)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
print("Test on CPU")

with tf.device("/cpu:0"):
    num_classes = 10
    input_shape = (28, 28, 1)
    (x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
    x_train = x_train.astype("float32") / 255
    x_test = x_test.astype("float32") / 255
    x_train = np.expand_dims(x_train, -1)
    x_test = np.expand_dims(x_test, -1)
    print("x_train shape:", x_train.shape)
    print(x_train.shape[0], "train samples")
    print(x_test.shape[0], "test samples")
    y_train = keras.utils.to_categorical(y_train, num_classes)
    y_test = keras.utils.to_categorical(y_test, num_classes)
    model = keras.Sequential(
        [
            keras.Input(shape=input_shape),
            layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
            layers.MaxPooling2D(pool_size=(2, 2)),
            layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
            layers.MaxPooling2D(pool_size=(2, 2)),
            layers.Flatten(),
            layers.Dropout(0.5),
            layers.Dense(num_classes, activation="softmax"),
        ]
    )
    model.summary()
    batch_size = 128
    epochs = 15
    model.compile(
        loss="categorical_crossentropy",
        optimizer="adam",
        metrics=["accuracy"]
    )
    model.fit(
        x_train,
        y_train,
        batch_size=batch_size,
        epochs=epochs,
        validation_split=0.1
    )
# Out:
# Test on CPU
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dropout (Dropout)           (None, 1600)              0
#
#  dense (Dense)               (None, 10)                16010
#
# =================================================================
# Total params: 34826 (136.04 KB)
# Trainable params: 34826 (136.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/15
# 422/422 [==============================] - 17s 39ms/step - loss: 0.3742 - accuracy: 0.8873 - val_loss: 0.0837 - val_accuracy: 0.9755
# Epoch 2/15
# 422/422 [==============================] - 19s 45ms/step - loss: 0.1112 - accuracy: 0.9658 - val_loss: 0.0566 - val_accuracy: 0.9853
# Epoch 3/15
# 422/422 [==============================] - 19s 45ms/step - loss: 0.0847 - accuracy: 0.9740 - val_loss: 0.0478 - val_accuracy: 0.9875
# Epoch 4/15
# 422/422 [==============================] - 20s 48ms/step - loss: 0.0707 - accuracy: 0.9786 - val_loss: 0.0405 - val_accuracy: 0.9902
# Epoch 5/15
# 422/422 [==============================] - 19s 46ms/step - loss: 0.0619 - accuracy: 0.9807 - val_loss: 0.0393 - val_accuracy: 0.9892
# Epoch 6/15
# 422/422 [==============================] - 19s 46ms/step - loss: 0.0554 - accuracy: 0.9836 - val_loss: 0.0374 - val_accuracy: 0.9890
# Epoch 7/15
# 422/422 [==============================] - 19s 45ms/step - loss: 0.0513 - accuracy: 0.9840 - val_loss: 0.0364 - val_accuracy: 0.9908
# Epoch 8/15
# 422/422 [==============================] - 19s 46ms/step - loss: 0.0475 - accuracy: 0.9853 - val_loss: 0.0334 - val_accuracy: 0.9908
# Epoch 9/15
# 422/422 [==============================] - 19s 45ms/step - loss: 0.0434 - accuracy: 0.9869 - val_loss: 0.0332 - val_accuracy: 0.9908
# Epoch 10/15
# 422/422 [==============================] - 19s 46ms/step - loss: 0.0431 - accuracy: 0.9862 - val_loss: 0.0305 - val_accuracy: 0.9922
# Epoch 11/15
# 422/422 [==============================] - 19s 46ms/step - loss: 0.0392 - accuracy: 0.9875 - val_loss: 0.0351 - val_accuracy: 0.9900
# Epoch 12/15
# 422/422 [==============================] - 19s 46ms/step - loss: 0.0359 - accuracy: 0.9887 - val_loss: 0.0297 - val_accuracy: 0.9927
# Epoch 13/15
# 422/422 [==============================] - 19s 46ms/step - loss: 0.0355 - accuracy: 0.9884 - val_loss: 0.0301 - val_accuracy: 0.9913
# Epoch 14/15
# 422/422 [==============================] - 19s 46ms/step - loss: 0.0337 - accuracy: 0.9888 - val_loss: 0.0324 - val_accuracy: 0.9920
# Epoch 15/15
# 422/422 [==============================] - 19s 46ms/step - loss: 0.0322 - accuracy: 0.9891 - val_loss: 0.0320 - val_accuracy: 0.9928

# %%
print("Test on GPU")

with tf.device("/gpu:0"):
    num_classes = 10
    input_shape = (28, 28, 1)
    (x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
    x_train = x_train.astype("float32") / 255
    x_test = x_test.astype("float32") / 255
    x_train = np.expand_dims(x_train, -1)
    x_test = np.expand_dims(x_test, -1)
    print("x_train shape:", x_train.shape)
    print(x_train.shape[0], "train samples")
    print(x_test.shape[0], "test samples")
    y_train = keras.utils.to_categorical(y_train, num_classes)
    y_test = keras.utils.to_categorical(y_test, num_classes)
    model = keras.Sequential(
        [
            keras.Input(shape=input_shape),
            layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
            layers.MaxPooling2D(pool_size=(2, 2)),
            layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
            layers.MaxPooling2D(pool_size=(2, 2)),
            layers.Flatten(),
            layers.Dropout(0.5),
            layers.Dense(num_classes, activation="softmax"),
        ]
    )
    model.summary()
    batch_size = 128
    epochs = 15
    model.compile(
        loss="categorical_crossentropy",
        optimizer="adam",
        metrics=["accuracy"]
    )
    model.fit(
        x_train, y_train,
        batch_size=batch_size,
        epochs=epochs,
        validation_split=0.1
    )
# Out:
# Test on GPU
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_2 (MaxPoolin  (None, 13, 13, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_3 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 1600)              0
#
#  dropout_1 (Dropout)         (None, 1600)              0
#
#  dense_1 (Dense)             (None, 10)                16010
#
# =================================================================
# Total params: 34826 (136.04 KB)
# Trainable params: 34826 (136.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/15
# 422/422 [==============================] - 18s 41ms/step - loss: 0.3647 - accuracy: 0.8888 - val_loss: 0.0882 - val_accuracy: 0.9767
# Epoch 2/15
# 422/422 [==============================] - 19s 45ms/step - loss: 0.1118 - accuracy: 0.9656 - val_loss: 0.0544 - val_accuracy: 0.9877
# Epoch 3/15
# 422/422 [==============================] - 20s 47ms/step - loss: 0.0827 - accuracy: 0.9753 - val_loss: 0.0522 - val_accuracy: 0.9862
# Epoch 4/15
# 422/422 [==============================] - 20s 48ms/step - loss: 0.0691 - accuracy: 0.9786 - val_loss: 0.0412 - val_accuracy: 0.9900
# Epoch 5/15
# 422/422 [==============================] - 20s 46ms/step - loss: 0.0607 - accuracy: 0.9821 - val_loss: 0.0364 - val_accuracy: 0.9898
# Epoch 6/15
# 422/422 [==============================] - 20s 47ms/step - loss: 0.0549 - accuracy: 0.9829 - val_loss: 0.0365 - val_accuracy: 0.9915
# Epoch 7/15
# 422/422 [==============================] - 20s 47ms/step - loss: 0.0487 - accuracy: 0.9844 - val_loss: 0.0365 - val_accuracy: 0.9903
# Epoch 8/15
# 422/422 [==============================] - 20s 46ms/step - loss: 0.0479 - accuracy: 0.9845 - val_loss: 0.0339 - val_accuracy: 0.9912
# Epoch 9/15
# 422/422 [==============================] - 20s 47ms/step - loss: 0.0409 - accuracy: 0.9866 - val_loss: 0.0337 - val_accuracy: 0.9913
# Epoch 10/15
# 422/422 [==============================] - 20s 47ms/step - loss: 0.0396 - accuracy: 0.9874 - val_loss: 0.0326 - val_accuracy: 0.9920
# Epoch 11/15
# 422/422 [==============================] - 19s 46ms/step - loss: 0.0391 - accuracy: 0.9876 - val_loss: 0.0302 - val_accuracy: 0.9920
# Epoch 12/15
# 422/422 [==============================] - 20s 48ms/step - loss: 0.0360 - accuracy: 0.9881 - val_loss: 0.0306 - val_accuracy: 0.9927
# Epoch 13/15
# 422/422 [==============================] - 20s 47ms/step - loss: 0.0355 - accuracy: 0.9886 - val_loss: 0.0308 - val_accuracy: 0.9910
# Epoch 14/15
# 422/422 [==============================] - 20s 47ms/step - loss: 0.0328 - accuracy: 0.9894 - val_loss: 0.0299 - val_accuracy: 0.9922
# Epoch 15/15
# 422/422 [==============================] - 20s 47ms/step - loss: 0.0327 - accuracy: 0.9897 - val_loss: 0.0276 - val_accuracy: 0.9927
